# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_combined = mouse_metadata.merge(study_results, how="inner", on="Mouse ID")
# Display the data table for preview
mouse_combined.head(20)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            45.000000                 0
# 1            38.825898                 0
# 2            35.014271                 1
# 3            34.223992                 1
# 4            32.997729                 1
# 5            33.464577                 1
# 6            31.099498                 1
# 7            26.546993                 1
# 8            24.365505                 1
# 9            22.050126                 1
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0
# 15           33.949940                 0
# 16           32.959671                 1
# 17           28.328531                 1
# 18           25.472143                 1
# 19           23.343598                 1

# %%
# Checking the number of mice / unique Mouse IDs
mouse_combined["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
temp_df = mouse_combined[["Mouse ID","Timepoint"]]
temp_df.loc[temp_df.duplicated() == True]
# Out:
#     Mouse ID  Timepoint
# 909     g989          0
# 911     g989          5
# 913     g989         10
# 915     g989         15
# 917     g989         20

# %%
# Duplicated data in full
mouse_combined.loc[temp_df.duplicated() == True]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_combined.loc[mouse_combined["Mouse ID"] == "g989"]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_combined_cleaned = mouse_combined.drop([908,909,910,911,912,913,914,915,916,917,918,919,920])

# %%
# Checking the number of mice in the clean DataFrame.
mouse_combined_cleaned["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# Select data
summary_df = mouse_combined_cleaned.groupby("Drug Regimen")["Tumor Volume (mm3)"]
# Build table
Summary_Table = pd.DataFrame({"Mean_Tumor_Volune(mm3)":summary_df.mean(), "Median_Tumor_Volume(mm3)":summary_df.median(), "Variance_Tumor_Volume(mm3)": summary_df.var(), "StdDev_Tumor_Volume(mm3)": summary_df.std(),"SEM_Tumor_Volume(mm3)": summary_df.sem()},)
# Format and publish table
Summary_Table.applymap("{:,.4}".format)
# Out:
#              Mean_Tumor_Volune(mm3) Median_Tumor_Volume(mm3)  \
# Drug Regimen
# Capomulin                     40.68                    41.56
# Ceftamin                      52.59                    51.78
# Infubinol                     52.88                    51.82
# Ketapril                      55.24                     53.7
# Naftisol                      54.33                    52.51
# Placebo                       54.03                    52.29
# Propriva                      52.32                    50.45
# Ramicane                      40.22                    40.67
# Stelasyn                      54.23                    52.43
# Zoniferol                     53.24                    51.82
#
#              Variance_Tumor_Volume(mm3) StdDev_Tumor_Volume(mm3)  \
# Drug Regimen
# Capomulin                         24.95                    4.995
# Ceftamin                          39.29                    6.268
# Infubinol                         43.13                    6.567
# Ketapril                          68.55                     8.28
# Naftisol                          66.17                    8.135
# Placebo                           61.17                    7.821
# Propriva                          43.85                    6.622
# Ramicane                          23.49                    4.846
# Stelasyn                          59.45                     7.71
# Zoniferol                         48.53                    6.967
#
#              SEM_Tumor_Volume(mm3)
# Drug Regimen
# Capomulin                   0.3293
# Ceftamin                    0.4698
# Infubinol                   0.4922
# Ketapril                    0.6039
# Naftisol                    0.5965
# Placebo                     0.5813
# Propriva                    0.5443
# Ramicane                     0.321
# Stelasyn                    0.5731
# Zoniferol                   0.5164

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
summary_df.agg(["mean", "median", "var", "std", "sem"]).applymap("{:,.4}".format)
# Out:
#                mean median    var    std     sem
# Drug Regimen
# Capomulin     40.68  41.56  24.95  4.995  0.3293
# Ceftamin      52.59  51.78  39.29  6.268  0.4698
# Infubinol     52.88  51.82  43.13  6.567  0.4922
# Ketapril      55.24   53.7  68.55   8.28  0.6039
# Naftisol      54.33  52.51  66.17  8.135  0.5965
# Placebo       54.03  52.29  61.17  7.821  0.5813
# Propriva      52.32  50.45  43.85  6.622  0.5443
# Ramicane      40.22  40.67  23.49  4.846   0.321
# Stelasyn      54.23  52.43  59.45   7.71  0.5731
# Zoniferol     53.24  51.82  48.53  6.967  0.5164

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
xlabel = "Drug Regimen"
ylabel = "Count of Mice"
title = "Total number of unique mice tested on each drug regimen"
mouse_combined_cleaned.groupby("Drug Regimen")["Mouse ID"].nunique().plot(kind="bar",title=title,xlabel = xlabel,ylabel=ylabel, legend = False)
# Out:
# <AxesSubplot:title={'center':'Total number of unique mice tested on each drug regimen'}, xlabel='Drug Regimen', ylabel='Count of Mice'>

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
x_axis = mouse_combined_cleaned["Drug Regimen"].unique()
tick_locations = [value for value in x_axis]
plt.bar(x_axis, mouse_combined_cleaned.groupby("Drug Regimen")["Mouse ID"].nunique(), color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, x_axis, rotation="vertical")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
timepointmax_df = mouse_combined_cleaned.groupby(["Mouse ID"])["Timepoint"].max()
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_df = pd.DataFrame(timepointmax_df).merge(mouse_combined_cleaned, how="inner", on="Mouse ID")
# Select only rows where timepoint is the maximum values and reduce rows
new_timepointmax_df = new_df.loc[new_df["Timepoint_x"]==new_df["Timepoint_y"]][["Drug Regimen","Mouse ID","Tumor Volume (mm3)"]]
# Select only Capomulin, Ramicane, Infubinol, and Ceftamin                                                   
final_tumor_size_df = new_timepointmax_df.loc[(new_timepointmax_df["Drug Regimen"] == "Capomulin") | 
                        (new_timepointmax_df["Drug Regimen"] == "Infubinol") | 
                        (new_timepointmax_df["Drug Regimen"] == "Ramicane") |
                        (new_timepointmax_df["Drug Regimen"] == "Ceftamin")]

# %%
# Dict = {}
# for x in range(len(final_tumor_size_df)):
#     treatment = final_tumor_size_df.iloc[row][0]
#     tumor_volume = final_tumor_size_df.iloc[row][1]
#     if treatment not in Dict:
#         Dict[treatment] = tumor_volume
#     else:
#         Dict[treatment].append(tumor_volume)
# Dict

# %%
# dict = {}
# regimen = "Infubinol"
# a_df = final_tumor_size_df.loc[final_tumor_size_df["Drug Regimen"]==regimen]["Tumor Volume (mm3)"]
# c = a_df.values.tolist()

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = {}; key_stats = {}; potential_outliers = {}

for treatment in treatments:
    #  Create a dict with treatments as keys and a tumor volumes list as values
    tumor_vol_data[treatment] = final_tumor_size_df.loc[final_tumor_size_df["Drug Regimen"]==treatment]["Tumor Volume (mm3)"].values.tolist()
    
    # Calculate statistics for each treatment
    
    lowerq = np.quantile(tumor_vol_data[treatment],0.25)
    upperq = np.quantile(tumor_vol_data[treatment],0.75)
    # Calculate the IQR and upper and lower bounds
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    # Populate new dict with key stats by treatment regimen
    key_stats[treatment] = [lowerq, upperq, iqr,lower_bound,upper_bound]

# Check for outliers
for treatment in treatments:
    for x in range(len(tumor_vol_data[treatment])):
        # check for outliers above upper_bound
        
        if tumor_vol_data[treatment][x] > key_stats[treatment][4]:
            a = "   Outlier (Upper)"
            print(f"{treatment} value {tumor_vol_data[treatment][x]} Upper: {key_stats[treatment][4]} Lower: {key_stats[treatment][3]} {a}")
            if treatment not in potential_outliers:
                potential_outliers[treatment] = tumor_vol_data[treatment][x]
            else:
                potential_outliers[treatment].append(tumor_vol_data[treatment][x])
        else:
            pass
        # check for outliers below lower_bound
        if tumor_vol_data[treatment][x] < key_stats[treatment][3]: 
            a = "Outlier (lower)"
            print(f"{treatment} value {tumor_vol_data[treatment][x]} Upper: {key_stats[treatment][4]} Lower: {key_stats[treatment][3]} {a}")
            if treatment not in potential_outliers:
                potential_outliers[treatment] = tumor_vol_data[treatment][x]
            else:
                potential_outliers[treatment].append(tumor_vol_data[treatment][x])
        else:
            pass
        print(f"{treatment} value {tumor_vol_data[treatment][x]} Upper: {key_stats[treatment][4]} Lower: {key_stats[treatment][3]}")
            
# determine if there are any potential outliers.
potential_outliers
# Out:
# Capomulin value 38.98287774 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 38.93963263 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 30.48598484 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 37.07402422 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 40.1592203 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 47.68596303 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 37.31184577 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 38.125164399999996 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 38.75326548 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 41.48300765 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 38.84687569 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 28.43096411 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 33.32909778 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 46.53920617 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 32.37735684 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 41.58152074 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 23.34359787 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 40.72857787 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 34.45529799 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 31.02392294 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 40.65812366 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 39.95234669 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 36.04104736 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 28.48403281 Upper: 51.83201549 Lower: 20.70456164999999
# Capomulin value 31.896238399999998 Upper: 51.83201549 Lower: 20.70456164999999
# Ramicane value 38.407618299999996 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 43.04754260000001 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 38.81036633 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 32.97852192 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 38.34200823 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 33.39765251 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 37.31123552 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 40.65900627 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 29.12847181 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 33.56240217 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 36.37451039 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 31.56046955 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 36.13485243 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 22.05012627 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 30.56462509 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 31.09533505 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 45.22086888 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 36.56165229 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 37.22565033 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 43.41938077 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 30.27623175 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 40.66771292 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 43.16637266 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 44.18345092 Upper: 54.30681135 Lower: 17.912664470000003
# Ramicane value 30.63869575 Upper: 54.30681135 Lower: 17.912664470000003
# Infubinol value 67.97341878 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 65.52574285 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 57.03186187 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 66.08306589 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 72.2267309 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 36.321345799999996 Upper: 82.74144559000001 Lower: 36.83290494999999 Outlier (lower)
# Infubinol value 36.321345799999996 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 60.96971133 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 62.43540402 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 60.91876652 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 67.28962147 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 66.19691151 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 62.11727887 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 47.01036401 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 60.16518046 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 55.62942846 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 45.69933088 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 54.65654872 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 55.65068132 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 46.25011212 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 54.04860769 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 51.54243058 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 50.00513807 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 58.26844248 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 67.68556862 Upper: 82.74144559000001 Lower: 36.83290494999999
# Infubinol value 62.75445141 Upper: 82.74144559000001 Lower: 36.83290494999999
# Ceftamin value 62.99935619 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 45.0 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 56.05774909 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 55.74282869 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 48.72207785 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 47.784681799999994 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 61.84902336 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 68.92318457 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 67.74866174 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 57.91838132 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 46.78453491 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 59.85195552 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 64.29983003 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 59.74190064 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 61.43389223 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 64.19234114 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 45.0 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 52.92534846 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 45.0 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 67.52748237 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 45.0 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 64.63494887 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 61.38666032 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 68.59474498 Upper: 87.66645829999999 Lower: 25.355449580000002
# Ceftamin value 64.72983655 Upper: 87.66645829999999 Lower: 25.355449580000002
# {'Infubinol': 36.321345799999996}

# %%
key_stats
# Out:
# {'Capomulin': [32.37735684,
#   40.1592203,
#   7.781863460000004,
#   20.70456164999999,
#   51.83201549],
#  'Ramicane': [31.56046955,
#   40.65900627,
#   9.098536719999998,
#   17.912664470000003,
#   54.30681135],
#  'Infubinol': [54.04860769,
#   65.52574285,
#   11.477135160000003,
#   36.83290494999999,
#   82.74144559000001],
#  'Ceftamin': [48.72207785,
#   64.29983003,
#   15.577752179999997,
#   25.355449580000002,
#   87.66645829999999]}

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# fig1, (ax1, ax2) = plt.subplots()

# fig1, ax1 = plt.subplots()
# # ax1.set_title('Temperatures at LAX')
# # ax1.set_ylabel('Temperature (°F)')
# ax1.boxplot(tumor_vol_data['Infubinol'])
# fig1, ax1 = plt.subplots()
# # ax1.set_title('Temperatures at LAX')
# # ax1.set_ylabel('Temperature (°F)')
# ax1.boxplot(tumor_vol_data['Capomulin'])
# plt.show()
final_tumor_size_df.loc[final_tumor_size_df["Drug Regimen"]=='Infubinol'].boxplot()
# final_tumor_size_df.loc[final_tumor_size_df["Drug Regimen"]=='Capomulin'].boxplot()
# final_tumor_size_df.loc[final_tumor_size_df["Drug Regimen"]=="Ceftamin"].boxplot()
# final_tumor_size_df.loc[final_tumor_size_df["Drug Regimen"]=='Infubinol'].boxplot()

# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
